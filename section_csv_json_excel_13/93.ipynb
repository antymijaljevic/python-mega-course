# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '89.py',
#  '90.py',
#  '92.py.ipynb',
#  '93.py.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %%
import pandas
df = pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df_2 = pandas.read_json("supermarkets.json")
df_2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
# pip3 install openpyxl < install to open new excel files
# pip3 install xlrd <  install to open old excel files

# %%
df_3 = pandas.read_excel("crypto.xlsx", sheet_name=0)
df_3
# Out:
#                    DATE  FILLED AT  INVESTED  COMMISSION  ASSET QTY.  \
# 0   2021-09-22 01:15:00       2.03     69.83      0.0344        34.4
# 1   2021-09-23 01:00:00       2.26     10.84      0.0048         4.8
# 2   2021-09-24 01:00:00       2.33     10.94      0.0047         4.7
# 3   2021-09-25 01:00:00       2.28     10.94      0.0048         4.8
# 4   2021-09-26 01:00:00       2.27     10.88      0.0048         4.8
# 5   2021-09-27 01:00:00       2.25     10.78      0.0048         4.8
# 6   2021-09-28 01:00:00       2.15     10.94      0.0051         5.1
# 7   2021-09-29 01:00:00       2.05     10.88      0.0053         5.3
# 8   2021-09-30 01:00:00       2.09     10.88      0.0052         5.2
# 9   2021-10-01 01:00:00       2.12     10.81      0.0051         5.1
# 10  2021-10-02 01:00:00       2.23     10.92      0.0049         4.9
# 11  2021-10-03 01:00:00       2.23     10.94      0.0049         4.9
# 12  2021-10-04 01:00:00       2.23     10.91      0.0049         4.9
# ...
