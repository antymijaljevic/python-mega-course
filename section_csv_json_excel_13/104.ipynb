# %%
import pandas

# %%
df = pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df = df.set_index("Address")
df
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df.loc["735 Dolores St": "332 Hill St", "Country": "Name"] # extract data
# Out:
#                Country         Name
# Address
# 735 Dolores St     USA  Bready Shop
# 332 Hill St        USA  Super River

# %%
one_thing = df.loc["332 Hill St", "Name"]
one_thing
# Out:
# 'Super River'

# %%
more_things = df.loc[:, "Name"]

# %%
more_things
# Out:
# Address
# 3666 21st St           Madeira
# 735 Dolores St     Bready Shop
# 332 Hill St        Super River
# 3995 23rd St        Ben's Shop
# 1056 Sanchez St        Sanchez
# 551 Alvarado St     Richvalley
# Name: Name, dtype: object

# %%
df = df.set_index("Address")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_47604/2743818098.py in <module>
# ----> 1 df = df.set_index("Address")
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['Address'] are in the columns"

# %%
df
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
something = df.loc[:,"Country"]
something
# Out:
# Address
# 3666 21st St       USA
# 735 Dolores St     USA
# 332 Hill St        USA
# 3995 23rd St       USA
# 1056 Sanchez St    USA
# 551 Alvarado St    USA
# Name: Country, dtype: object

# %%
list(something)
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df7 = df

# %%
df7
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df["Continent"] = df.shape[0]*["North America"]

# %%
df
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees      Continent
# Address
# 3666 21st St             8  North America
# 735 Dolores St          15  North America
# 332 Hill St             25  North America
# 3995 23rd St            10  North America
# 1056 Sanchez St         12  North America
# 551 Alvarado St         20  North America

# %%
df.shape
# Out:
# (6, 7)

# %%
df.shape[0]
# Out:
# 6

# %%
df.shape[0]*["North America"]
# Out:
# ['North America',
#  'North America',
#  'North America',
#  'North America',
#  'North America',
#  'North America']

# %%
df['Continent'] = df['Continent'] + "," + "North America"

# %%
df
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees                    Continent
# Address
# 3666 21st St             8  North America,North America
# 735 Dolores St          15  North America,North America
# 332 Hill St             25  North America,North America
# 3995 23rd St            10  North America,North America
# 1056 Sanchez St         12  North America,North America
# 551 Alvarado St         20  North America,North America

# %%
df_t = df.T

# %%
df_t
# Out:
# Address                   3666 21st St               735 Dolores St  \
# ID                                   1                            2
# City                     San Francisco                San Francisco
# State                         CA 94114                     CA 94119
# Country                            USA                          USA
# Name                           Madeira                  Bready Shop
# Employees                            8                           15
# Continent  North America,North America  North America,North America
#
# Address                    332 Hill St                 3995 23rd St  \
# ID                                   3                            4
# City                     San Francisco                San Francisco
# State                 California 94114                     CA 94114
# Country                            USA                          USA
# Name                       Super River                   Ben's Shop
# ...

# %%
df_t["My address"] = ["A", "brate", "je", "ga", "upilo", 7, 8]

# %%
df_t
# Out:
# Address                   3666 21st St               735 Dolores St  \
# ID                                   1                            2
# City                     San Francisco                San Francisco
# State                         CA 94114                     CA 94119
# Country                            USA                          USA
# Name                           Madeira                  Bready Shop
# Employees                            8                           15
# Continent  North America,North America  North America,North America
#
# Address                    332 Hill St                 3995 23rd St  \
# ID                                   3                            4
# City                     San Francisco                San Francisco
# State                 California 94114                     CA 94114
# Country                            USA                          USA
# Name                       Super River                   Ben's Shop
# ...

# %%
df7 = df_t.T

# %%
df7
# Out:
#                 ID           City             State Country         Name  \
# Address
# 3666 21st St     1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      3  San Francisco  California 94114     USA  Super River
# 3995 23rd St     4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  5  San Francisco        California     USA      Sanchez
# 551 Alvarado St  6  San Francisco          CA 94114     USA   Richvalley
# My address       A          brate                je      ga        upilo
#
#                 Employees                    Continent
# Address
# 3666 21st St            8  North America,North America
# 735 Dolores St         15  North America,North America
# 332 Hill St            25  North America,North America
# 3995 23rd St           10  North America,North America
# 1056 Sanchez St        12  North America,North America
# ...
